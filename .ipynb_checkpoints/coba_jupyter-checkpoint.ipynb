# %%
import numpy as np

# %%
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.05657270731557843), np.float64(1.0169958754763904))

# %%
# %timeit np.random.randn(10000)
# Out:
# 178 μs ± 6.51 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

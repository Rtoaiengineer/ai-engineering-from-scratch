# %%
import random
import numpy as np

# %%
# %timeit [random.random() for _ in range(100000)]
# Out:
# 5.82 ms ± 398 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.random.randn(100000)
# Out:
# 2.21 ms ± 225 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Markdown, Data, Grafik, dan Mencegah Error

# %%
# %matplotlib inline

# %%
import pandas as pd

df= pd.DataFrame({
    "model":["Linier","Random Forest","Neural Net"],
    "accuracy":[0.9, 0.87, 0.63],
    "training_Time":[0.12, 0.15, 0.65]
    
})
df
# Out:
#            model  accuracy  training_Time
# 0         Linier      0.90           0.12
# 1  Random Forest      0.87           0.15
# 2     Neural Net      0.63           0.65

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 3, 4, 2])
plt.title("Inline plot")
plt.show()

# %%
df.to_csv("data_latihan.csv", index=False)

# %%
pd.read_csv("data_latihan.csv")
# Out:
#            model  accuracy  training_Time
# 0         Linier      0.90           0.12
# 1  Random Forest      0.87           0.15
# 2     Neural Net      0.63           0.65
